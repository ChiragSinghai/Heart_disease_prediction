# %% [markdown]
# ## importing libraries for visualization and data preprocessing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# **importing the csv file and reviewing the data**

# %%
df=pd.read_csv('Heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ### checking if any null value exists in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# ### Understanding the data

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]

for i in range(len(info)):
    print(df.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df['target']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
print('0: no. of people not having a heart disease\n1: no. of people having heart disease')
df.groupby('target').size()
# Out:
# 0: no. of people not having a heart disease
# 1: no. of people having heart disease
# target
# 0    138
# 1    165
# dtype: int64

# %% [markdown]
# # Visualization

# %%
plt.hist(df['target'])
plt.show()

# %%
df.hist(figsize=(14,14))
plt.show()

# %%
sns.countplot(df['target'])

# %%
sns.barplot(x='sex',y='age',data=df)
plt.show()

# %%
sns.countplot(df['restecg'])
plt.show()

# %%
sns.barplot(x='sex',y='age',hue='target',data=df)
plt.show()

# %%
sns.barplot(df["cp"],df['target'])
plt.show()

# %% [markdown]
# **it can be seen by viewing data that the five columns i.e  ['trestbps','chol','thalach','age','oldpeak'] are columns that
# have some correlation between them**

# %%
col=['trestbps','chol','thalach','age','oldpeak']

# %%
sns.distplot(df['trestbps'])
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.subplot(321)
sns.distplot(df['trestbps'])
plt.subplot(322)
sns.distplot(df['age'])
plt.subplot(323)
sns.distplot(df['thalach'])
plt.subplot(324)
sns.distplot(df['chol'])
plt.subplot(325)
sns.distplot(df['oldpeak'])
plt.show()

# %% [markdown]
# ## understanding correlaion between these features

# %%
sns.pairplot(df[col])
plt.show()

# %%
df[col].corr()
# Out:
#           trestbps      chol   thalach       age   oldpeak
# trestbps  1.000000  0.123174 -0.046698  0.279351  0.193216
# chol      0.123174  1.000000 -0.009940  0.213678  0.053952
# thalach  -0.046698 -0.009940  1.000000 -0.398522 -0.344187
# age       0.279351  0.213678 -0.398522  1.000000  0.210013
# oldpeak   0.193216  0.053952 -0.344187  0.210013  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[col].corr(),annot=True,cmap='Oranges')
plt.show()

# %%
#sns.violinplot(x="target", y="thalach", data=df, inner=None)
#sns.swarmplot(x="target", y="thalach", data=df, color='w', alpha=0.5)
sns.swarmplot(x="target", y="thalach", data=df)
plt.show()

# %%
sns.pointplot(x="sex", y="target", hue='cp', data=df)
#plt.legend(['male = 1', 'female = 0'])

# %%
sns.countplot(x="sex", hue='target', data=df)
plt.show()

# %%
df.groupby('target')['sex'].value_counts()
# Out:
# target  sex
# 0       1      114
#         0       24
# 1       1       93
#         0       72
# Name: sex, dtype: int64

# %% [markdown]
# ## data preprocessing

# %%
X,Y=df.loc[:,:'thal'],df['target']

# %%
X.shape
# Out:
# (303, 13)

# %%
Y.shape
# Out:
# (303,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
print ("train_set_x shape: " + str(X_train.shape))
print ("train_set_y shape: " + str(Y_train.shape))
print ("test_set_x shape: " + str(X_test.shape))
print ("test_set_y shape: " + str(Y_test.shape))
# Out:
# train_set_x shape: (242, 13)
# train_set_y shape: (242,)
# test_set_x shape: (61, 13)
# test_set_y shape: (61,)

# %%
X_train0,X_test0,Y_train0,Y_test0=train_test_split(X,Y,test_size=0.3)
print ("train_set_x shape: " + str(X_train0.shape))
print ("train_set_y shape: " + str(Y_train0.shape))
print ("test_set_x shape: " + str(X_test0.shape))
print ("test_set_y shape: " + str(Y_test0.shape))
# Out:
# train_set_x shape: (212, 13)
# train_set_y shape: (212,)
# test_set_x shape: (91, 13)
# test_set_y shape: (91,)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.metrics import confusion_matrix, classification_report 
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=dt.predict(X_test)
accuracy_dt=accuracy_score(Y_test,prediction)*100
accuracy_dt
#dt.score(X_test,Y_test)
#print(X_test.shape,Y_test.shape)
# Out:
# 83.60655737704919

# %%
print("Feature importances:\n{}".format(dt.feature_importances_))
# Out:
# Feature importances:
# [0.09191332 0.03408768 0.12341525 0.09642749 0.07829752 0.
#  0.01126865 0.0383867  0.00219113 0.16442876 0.00845149 0.09567563
#  0.25545637]

# %%
dt_1=DecisionTreeClassifier()
dt_1.fit(X_train0,Y_train0)
predic=dt_1.predict(X_test0)
accuracy=accuracy_score(Y_test0,predic)*100
accuracy
# Out:
# 73.62637362637363

# %%
def plot_feature_importances_diabetes(model,data):
    n_features=data.shape[1]
    
    plt.figure(figsize=(8,6))
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features),data)
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")
    plt.ylim(-1, n_features)
plot_feature_importances_diabetes(dt,X_train)
plt.savefig('feature_importance')

# %%
X_train1=X_train.drop('fbs',axis=1)
X_test1=X_test.drop('fbs',axis=1)
print ("train_set_x shape: " + str(X_train1.shape))
print ("train_set_y shape: " + str(Y_train.shape))
print ("test_set_x shape: " + str(X_test1.shape))
print ("test_set_y shape: " + str(Y_test.shape))
dt1=DecisionTreeClassifier()
dt1.fit(X_train1,Y_train)
# Out:
# train_set_x shape: (242, 12)
# train_set_y shape: (242,)
# test_set_x shape: (61, 12)
# test_set_y shape: (61,)
# DecisionTreeClassifier()

# %%
pre=dt1.predict(X_test1)
a=accuracy_score(pre,Y_test)*100
a
# Out:
# 75.40983606557377

# %%
cm = confusion_matrix(Y_test,pre) 
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (8, 5)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens") 
plt.show() 
#plt.savefig('Accuracy_decision')

# %%
plot_feature_importances_diabetes(dt1,X_train1)

# %%
Catagory=['No the Patient doesnt have heart disease','Yes the patient have Heart Disease']
input_data=np.array([[63 ,1, 3,145,233,1,0,150,0,2.3,0,0,1]])
X_DT_prediction=dt.predict(input_data)
print(Catagory[int(X_DT_prediction[0])])
# Out:
# Yes the patient have Heart Disease

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler().fit(X)
X_train_std=sc.transform(X_train)
X_test_std=sc.transform(X_test)
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train_std,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
prediction_knn=knn.predict(X_test_std)
accuracy_knn=accuracy_score(Y_test,prediction_knn)*100
accuracy_knn
# Out:
# 83.60655737704919

# %%
cm = confusion_matrix(Y_test,prediction) 
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (8, 5)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens") 
plt.show()

# %%
print("Accuracy on training set: {:.3f}".format(knn.score(X_train_std, Y_train)))
print("Accuracy on test set: {:.3f}".format(knn.score(X_test_std,Y_test)))
# Out:
# Accuracy on training set: 0.860
# Accuracy on test set: 0.836

# %%
knn.score(X_test_std, Y_test)
# Out:
# 0.8360655737704918

# %%
k_range=range(1,26)
scores={}
scores_list=[]
for k in k_range:
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_std,Y_train)
    prediction_knn=knn.predict(X_test_std)
    scores[k]=accuracy_score(Y_test,prediction_knn)
    scores_list.append(accuracy_score(Y_test,prediction_knn))

# %%
scores
# Out:
# {1: 0.7704918032786885,
#  2: 0.7704918032786885,
#  3: 0.7540983606557377,
#  4: 0.8360655737704918,
#  5: 0.7540983606557377,
#  6: 0.819672131147541,
#  7: 0.819672131147541,
#  8: 0.8360655737704918,
#  9: 0.7704918032786885,
#  10: 0.8360655737704918,
#  11: 0.8360655737704918,
#  12: 0.8360655737704918,
#  13: 0.819672131147541,
#  14: 0.819672131147541,
#  15: 0.7868852459016393,
#  16: 0.8032786885245902,
#  17: 0.7704918032786885,
#  18: 0.7704918032786885,
#  19: 0.7540983606557377,
#  20: 0.7704918032786885,
#  21: 0.7540983606557377,
#  22: 0.7540983606557377,
#  23: 0.7377049180327869,
#  24: 0.7704918032786885,
#  25: 0.7704918032786885}

# %%
plt.plot(k_range,scores_list)
plt.xticks(k_range)
plt.show()
#plt.savefig('KNN_accuracy')

# %%
X_knn=np.array([[63 ,1, 3,145,233,1,0,150,0,2.3,0,0,1]])
X_knn_std=sc.transform(X_knn)
X_knn_prediction=dt.predict(X_knn)
X_knn_prediction[0]
# Out:
# 1

# %% [markdown]
# # logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression() 
logreg.fit(X_train_std, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test_std) 
log_acc=accuracy_score(Y_test,y_pred)*100
log_acc
# Out:
# 78.68852459016394

# %%
logreg.coef_
# Out:
# array([[-0.0018126 , -0.64787932,  0.69478027, -0.34056123, -0.335289  ,
#          0.07126799,  0.27637753,  0.5602186 , -0.41089121, -0.49860675,
#          0.30322961, -0.63261815, -0.63886014]])

# %%
n_features=X_train_std.shape[1]
plt.figure(figsize=(8,6))
plt.barh(range(n_features), logreg.coef_[0], align='center')
plt.yticks(np.arange(n_features),X_train)
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.ylim(-1, n_features)
plt.show()

# %%
cm = confusion_matrix(Y_test,y_pred) 
conf_matrix = pd.DataFrame(data = cm,  
                           columns = ['Predicted:0', 'Predicted:1'],  
                           index =['Actual:0', 'Actual:1']) 
plt.figure(figsize = (8, 5)) 
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = "Greens") 
plt.show()

# %%
algorithms=['Decision Tree 1','Decision Tree 2','Decision Tree imporved','KNN','Logistic Regression']
scores=[accuracy_dt,accuracy,a,accuracy_knn,log_acc]
sns.barplot(algorithms,scores)
plt.xticks(rotation=45)
plt.show()
#plt.savefig('all model')
